# %% [markdown]
# ## DATA COLLECTION
# ##### chEMBL is an open large-scale bioactivity database.
# ##### chembl_webresource_client is the library developed and supported by chEMBL group. The library helps accessing chEMBL data.

# %%
import pandas as pd #for data processing 
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ###### Lets download the biological activity data from chEMBL database. The dataset  is comprised of compounds that have been biologically tested for their activity towards target ######

# %%
target = new_client.target  
target_query = target.search('FLT3')  #search the target,'FLT3' is genetic code for Tyrosine protein kinase receptor
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references      organism  \
# 0                                                 []  Mus musculus
# 1  [{'xref_id': 'P36888', 'xref_name': None, 'xre...  Homo sapiens
#
#                                     pref_name  score  species_group_flag  \
# 0  Receptor-type tyrosine-protein kinase FLT3   18.0               False
# 1       Tyrosine-protein kinase receptor FLT3   16.0               False
#
#   target_chembl_id                                  target_components  \
# 0    CHEMBL2034796  [{'accession': 'Q00342', 'component_descriptio...
# 1       CHEMBL1974  [{'accession': 'P36888', 'component_descriptio...
#
#       target_type  tax_id
# 0  SINGLE PROTEIN   10090
# 1  SINGLE PROTEIN    9606

# %%
#selecting our target
selected_target = targets.target_chembl_id[1]  
selected_target
# Out:
# 'CHEMBL1974'

# %% [markdown]
# ##### Lets retrieve biological activity data for Tyrosine Protein kinase receptor that are reported as IC50 values in nM

# %%
activity = new_client.activity  
data = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
#convert data to dataframe using pandas 
df = pd.DataFrame.from_dict(data)
df.head()
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None       866063                  []    CHEMBL766072
# 1             None       872532                  []    CHEMBL766072
# 2             None       872564                  []    CHEMBL766072
# 3             None       879718                  []    CHEMBL766072
# 4             None       884645                  []    CHEMBL766072
#
#                                    assay_description assay_type bao_endpoint  \
# 0  Inhibition of chimeric PDGF receptor with FLT-...          B  BAO_0000190
# 1  Inhibition of chimeric PDGF receptor with FLT-...          B  BAO_0000190
# 2  Inhibition of chimeric PDGF receptor with FLT-...          B  BAO_0000190
# 3  Inhibition of chimeric PDGF receptor with FLT-...          B  BAO_0000190
# 4  Inhibition of chimeric PDGF receptor with FLT-...          B  BAO_0000190
#
#     bao_format          bao_label  \
# 0  BAO_0000219  cell-based format
# 1  BAO_0000219  cell-based format
# 2  BAO_0000219  cell-based format
# 3  BAO_0000219  cell-based format
# 4  BAO_0000219  cell-based format
#
#                                     canonical_smiles  ... target_organism  \
# 0  COc1cc2c(N3CCN(C(=O)Nc4ccc(OC(C)C)cc4)CC3)ncnc...  ...    Homo sapiens
# 1  COc1cc2c(N3CCN(C(=O)Nc4ccc(OC(C)C)cc4)CC3)ncnc...  ...    Homo sapiens
# 2  COc1cc2c(N3CCN(C(=O)Nc4ccc(C#N)cc4)CC3)ncnc2cc...  ...    Homo sapiens
# 3  COc1cc2c(N3CCN(C(=O)Nc4ccc(C#N)cc4)CC3)ncnc2cc...  ...    Homo sapiens
# 4  Cc1ccc(NC(=O)c2ccc(CN3CCN(C)CC3)cc2)cc1Nc1nccc...  ...    Homo sapiens
#
#                         target_pref_name target_tax_id text_value  toid  type  \
# 0  Tyrosine-protein kinase receptor FLT3          9606       None  None  IC50
# 1  Tyrosine-protein kinase receptor FLT3          9606       None  None  IC50
# 2  Tyrosine-protein kinase receptor FLT3          9606       None  None  IC50
# 3  Tyrosine-protein kinase receptor FLT3          9606       None  None  IC50
# 4  Tyrosine-protein kinase receptor FLT3          9606       None  None  IC50
#
#   units    uo_units upper_value  value
# 0    uM  UO_0000065        None  0.128
# 1    uM  UO_0000065        None   0.22
# 2    uM  UO_0000065        None   8.79
# 3    uM  UO_0000065        None   1.91
# 4    uM  UO_0000065        None   30.0
#
# [5 rows x 43 columns]

# %%
#dimension of dataframe 
df.shape
# Out:
# (3464, 43)

# %%
#removing data which has 'Nan' standard value 
df2 = df[df.standard_value.notna()]
df2.head()
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None       866063                  []    CHEMBL766072
# 1             None       872532                  []    CHEMBL766072
# 2             None       872564                  []    CHEMBL766072
# 3             None       879718                  []    CHEMBL766072
# 4             None       884645                  []    CHEMBL766072
#
#                                    assay_description assay_type bao_endpoint  \
# 0  Inhibition of chimeric PDGF receptor with FLT-...          B  BAO_0000190
# 1  Inhibition of chimeric PDGF receptor with FLT-...          B  BAO_0000190
# 2  Inhibition of chimeric PDGF receptor with FLT-...          B  BAO_0000190
# 3  Inhibition of chimeric PDGF receptor with FLT-...          B  BAO_0000190
# 4  Inhibition of chimeric PDGF receptor with FLT-...          B  BAO_0000190
#
#     bao_format          bao_label  \
# 0  BAO_0000219  cell-based format
# 1  BAO_0000219  cell-based format
# 2  BAO_0000219  cell-based format
# 3  BAO_0000219  cell-based format
# 4  BAO_0000219  cell-based format
#
#                                     canonical_smiles  ... target_organism  \
# 0  COc1cc2c(N3CCN(C(=O)Nc4ccc(OC(C)C)cc4)CC3)ncnc...  ...    Homo sapiens
# 1  COc1cc2c(N3CCN(C(=O)Nc4ccc(OC(C)C)cc4)CC3)ncnc...  ...    Homo sapiens
# 2  COc1cc2c(N3CCN(C(=O)Nc4ccc(C#N)cc4)CC3)ncnc2cc...  ...    Homo sapiens
# 3  COc1cc2c(N3CCN(C(=O)Nc4ccc(C#N)cc4)CC3)ncnc2cc...  ...    Homo sapiens
# 4  Cc1ccc(NC(=O)c2ccc(CN3CCN(C)CC3)cc2)cc1Nc1nccc...  ...    Homo sapiens
#
#                         target_pref_name target_tax_id text_value  toid  type  \
# 0  Tyrosine-protein kinase receptor FLT3          9606       None  None  IC50
# 1  Tyrosine-protein kinase receptor FLT3          9606       None  None  IC50
# 2  Tyrosine-protein kinase receptor FLT3          9606       None  None  IC50
# 3  Tyrosine-protein kinase receptor FLT3          9606       None  None  IC50
# 4  Tyrosine-protein kinase receptor FLT3          9606       None  None  IC50
#
#   units    uo_units upper_value  value
# 0    uM  UO_0000065        None  0.128
# 1    uM  UO_0000065        None   0.22
# 2    uM  UO_0000065        None   8.79
# 3    uM  UO_0000065        None   1.91
# 4    uM  UO_0000065        None   30.0
#
# [5 rows x 43 columns]

# %%
df2.shape
# Out:
# (3383, 43)

# %% [markdown]
# ##### 81 entries with NaN value are removed
#
# #### Lets Combine all those features/columns that are important for model training

# %%
columns= ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2[columns]
df3.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL330863  COc1cc2c(N3CCN(C(=O)Nc4ccc(OC(C)C)cc4)CC3)ncnc...
# 1       CHEMBL124660  COc1cc2c(N3CCN(C(=O)Nc4ccc(OC(C)C)cc4)CC3)ncnc...
# 2       CHEMBL126699  COc1cc2c(N3CCN(C(=O)Nc4ccc(C#N)cc4)CC3)ncnc2cc...
# 3       CHEMBL445636  COc1cc2c(N3CCN(C(=O)Nc4ccc(C#N)cc4)CC3)ncnc2cc...
# 4          CHEMBL941  Cc1ccc(NC(=O)c2ccc(CN3CCN(C)CC3)cc2)cc1Nc1nccc...
#
#   standard_value
# 0          128.0
# 1          220.0
# 2         8790.0
# 3         1910.0
# 4        30000.0

# %% [markdown]
# #### Labeling the compounds as Active/Inactive/Intermediate
#
# Compunds are being labeled(Active\Inactive\Intermediate) based on their potency value(Standard_values)
# compounds having values < 1000 nM will be considered active , Those greater than 10000 nM will be considered to be inactive

# %%
bioactivity_threshold = []
for i in df3.standard_value:
    if float(i) >= 10000:
        bioactivity_threshold.append("inactive")
    elif float(i) <= 1000:
        bioactivity_threshold.append("active")
    else:
        bioactivity_threshold.append("intermediate")

# %% [markdown]
# #### Let's Add Bioactivity data to our dataset

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='bioactivity')
df5 = pd.concat([df3, bioactivity_class], axis=1)
df5.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL330863  COc1cc2c(N3CCN(C(=O)Nc4ccc(OC(C)C)cc4)CC3)ncnc...
# 1       CHEMBL124660  COc1cc2c(N3CCN(C(=O)Nc4ccc(OC(C)C)cc4)CC3)ncnc...
# 2       CHEMBL126699  COc1cc2c(N3CCN(C(=O)Nc4ccc(C#N)cc4)CC3)ncnc2cc...
# 3       CHEMBL445636  COc1cc2c(N3CCN(C(=O)Nc4ccc(C#N)cc4)CC3)ncnc2cc...
# 4          CHEMBL941  Cc1ccc(NC(=O)c2ccc(CN3CCN(C)CC3)cc2)cc1Nc1nccc...
#
#   standard_value   bioactivity
# 0          128.0        active
# 1          220.0        active
# 2         8790.0  intermediate
# 3         1910.0  intermediate
# 4        30000.0      inactive

# %%
df5.bioactivity.value_counts()
# Out:
# active          1645
# inactive        1283
# intermediate     455
# Name: bioactivity, dtype: int64

# %% [markdown]
# ###### There are 1645 Active and 1283 inactive compounds/molecules present in our dataset

# %% [markdown]
# ##### Lets save this dataset

# %%
df5.to_csv('TPKR_data2.csv',index=False)
